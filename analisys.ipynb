# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from collections import Counter

# %%
df = pd.read_csv('out/llm_result.csv')
df.head()
# Out:
#   категория_товара   бренд категория_вопроса  \
# 0          гигиена  Always         брендовые
# 1          гигиена  Always         брендовые
# 2          гигиена  Always         брендовые
# 3          гигиена  Always         брендовые
# 4          гигиена  Always         брендовые
#
#                                               запрос  \
# 0  Always Platinum vs Always Ultra: основные отличия
# 1  Где заказать Always в большой упаковке (Big Pa...
# 2            Где найти Always Ultra Normal по акции?
# 3    Есть ли у Always экологичные линейки прокладок?
# 4         Какие размеры есть в линейке Always Ultra?
#
#                                         текст_ответа  \
# 0  Always Platinum и Always Ultra — это линейки г...
# 1  Прокладки Always в большой упаковке (Big Pack)...
# 2  Прокладки Always Ultra Normal можно найти по а...
# 3  В доступных источниках не удалось найти информ...
# 4  В линейке прокладок Always Ultra представлены ...
#
# ...

# %%
df.describe()
# Out:
#        q_brand_direct  q_comp_direct   a_pg_rank  a_is_winner  \
# count      240.000000     240.000000  240.000000   240.000000
# mean         0.441667       0.004167    0.770833     0.037500
# std          0.497623       0.064550    1.345060     0.190381
# min          0.000000       0.000000    0.000000     0.000000
# 25%          0.000000       0.000000    0.000000     0.000000
# 50%          0.000000       0.000000    1.000000     0.000000
# 75%          1.000000       0.000000    1.000000     0.000000
# max          1.000000       1.000000   14.000000     1.000000
#
#        a_pg_portfolio_count  a_comp_count  a_comp_is_winner  a_sentiment  \
# count            240.000000    240.000000        240.000000   240.000000
# mean               0.862500      1.483333          0.045833     0.329167
# std                1.161557      2.469846          0.209561     0.479696
# min                0.000000      0.000000          0.000000    -1.000000
# ...

# %% [markdown]
# Index(['категория_товара', 'бренд', 'категория_вопроса', 'запрос',
#        'текст_ответа', 'ссылки_в_тексте', 'сайты_в_тексте',
#        'ссылки_из_блока_источников', 'сайты_из_блока_источников',
#        'q_brand_direct', 'q_comp_direct', 'a_pg_rank', 'a_is_winner',
#        'a_pg_portfolio_count', 'a_comp_count', 'a_main_competitor',
#        'a_comp_is_winner', 'a_sentiment', 'a_has_tech', 'a_has_price',
#        'a_buy_cta', 'a_comparison_type', 'a_source_trust'],
#       dtype='str')
